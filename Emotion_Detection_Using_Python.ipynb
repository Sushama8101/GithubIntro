# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushama8101/GithubIntro/blob/master/Emotion_Detection_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## import package
# !pip install deepface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 65 kB 569 kB/s
# ...
#      |████████████████████████████████| 2.3 MB 31.5 MB/s
# ...
#      |████████████████████████████████| 87 kB 6.4 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=5c33648fc37e0176a8e1d95aff8557006f32bd0cbf52d30d7735b2bb5bd38257
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
#load and display image
import cv2
import matplotlib.pyplot as plt
img1=cv2.imread("/content/surprised man.jpg")
plt.imshow(img1[:,:,::-1])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# analyse image
result=DeepFace.analyze(img1, actions= ['emotion'])
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 38.0MB/s]

# %%
# print result
print(result)
# Out:
# {'emotion': {'angry': 6.663113832473755, 'disgust': 7.42286516697277e-06, 'fear': 9.873020648956299, 'happy': 0.0001761530370458786, 'sad': 9.563571959733963, 'surprise': 0.0020437395505723543, 'neutral': 73.89807105064392}, 'dominant_emotion': 'neutral', 'region': {'x': 190, 'y': 68, 'w': 64, 'h': 64}}
